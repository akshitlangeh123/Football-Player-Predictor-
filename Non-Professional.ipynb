# %% [markdown]
# ##Importing Libraries and the Dataset

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/content/drive/MyDrive/BDA MiniProj/preprocessed_data.csv")

# %%
df.head()
# Out:
#    Unnamed: 0         short_name  value_eur  wage_eur  preferred_foot  \
# 0           0           L. Messi   67500000    560000               0
# 1           1  Cristiano Ronaldo   46000000    220000               1
# 2           2           J. Oblak   75000000    125000               1
# 3           3     R. Lewandowski   80000000    240000               1
# 4           4          Neymar Jr   90000000    270000               1
#
#    team_position  weak_foot  skill_moves  age  work_rate  ...  \
# 0              0          4            4   33          7  ...
# 1             13          4            5   35          1  ...
# 2              5          3            1   27          8  ...
# 3             27          4            4   31          2  ...
# 4             14          5            5   28          2  ...
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# 0                         35                        24                   6
# ...

# %%
nr = df.columns[[0,2,3]]

# %%
df.drop(nr,axis=1,inplace=True)

# %%
df.head()
# Out:
#           short_name  preferred_foot  team_position  weak_foot  skill_moves  \
# 0           L. Messi               0              0          4            4
# 1  Cristiano Ronaldo               1             13          4            5
# 2           J. Oblak               1              5          3            1
# 3     R. Lewandowski               1             27          4            4
# 4          Neymar Jr               1             14          5            5
#
#    age  work_rate  team_jersey_number  pace  shooting  ...  \
# 0   33          7                10.0  85.0      92.0  ...
# 1   35          1                 7.0  89.0      93.0  ...
# 2   27          8                13.0  30.0      30.0  ...
# 3   31          2                 9.0  78.0      91.0  ...
# 4   28          2                10.0  91.0      85.0  ...
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# ...

# %%
df.shape
# Out:
# (18719, 56)

# %%
df.work_rate.unique()
# Out:
# array([7, 1, 8, 2, 0, 6, 3, 5, 4])

# %%
df.team_position.unique()
# Out:
# array([ 0, 13,  5, 27, 14, 19,  8, 25, 28,  3,  2, 20, 24,  9, 17,  7, 12,
#        18, 11,  1, 23, 10, 22, 21, 15,  4,  6, 26, 16])

# %%
df.preferred_foot.unique()
# Out:
# array([0, 1])

# %% [markdown]
# ##Traing Model

# %%
X1 = df.iloc[:,1:53].values
X2 = df.iloc[:,2:53].values
X3 = df.iloc[:,2:53].values
y1 = df.iloc[:,53].values
y2 = df.iloc[:,54].values
y3 = df.iloc[:,55].values

# %%
print(y2)
# Out:
# [93 92 91 ... 47 47 47]

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X1 = sc.fit_transform(X1)
X2 = sc.fit_transform(X2)
X3 = sc.fit_transform(X3)

# %%
from sklearn.svm import SVC
classifier = SVC(kernel='rbf',random_state=0)
classifier.fit(X1,y1)
# Out:
# SVC(random_state=0)

# %%
from sklearn.linear_model import LinearRegression
from sklearn.preprocessing import PolynomialFeatures
poly_reg = PolynomialFeatures(degree = 1)
X2_poly = poly_reg.fit_transform(X2)
lin_reg = LinearRegression()
regressor1 = lin_reg.fit(X2_poly,y2)

# %%
poly_reg_ = PolynomialFeatures(degree = 1)
X3_poly = poly_reg_.fit_transform(X3)
lin_reg = LinearRegression()
regressor2 = lin_reg.fit(X3_poly,y3)

# %% [markdown]
# ##Importing the Non-Professional Player dataset

# %%
df2 = pd.read_csv("/content/drive/MyDrive/BDA MiniProj/non-professional - non-professional.csv")
df2.head()
# Out:
#             short_name preferred_foot team_position  weak_foot  skill_moves  \
# 0       Ilias Akhomach           Left            RW          4            4
# 1              Ez Abde          Right            LW          4            4
# 2      Matheus Pereira           Left           RAM          3            3
# 3  Maarten Vandevoordt          Right            GK          2            1
# 4        M Morgenstern          Right            CB          2            2
#
#    age      work_rate  team_jersey_number  pace  shooting  ...  \
# 0   17  Medium/Medium                  27    85        70  ...
# 1   20    High/Medium                  20    85        75  ...
# 2   23  Medium/Medium                  12    74        80  ...
# 3   21        Low/Low                   1    54        20  ...
# 4   20    Medium/High                   4    21        34  ...
#
#    defending_standing_tackle  defending_sliding_tackle  goalkeeping_diving  \
# ...

# %% [markdown]
# ##Encoding the Categorical Data

# %%
objList = df2.select_dtypes(include = "object").columns
print (objList)
# Out:
# Index(['short_name', 'preferred_foot', 'team_position', 'work_rate'], dtype='object')

# %%
a = {'Medium/Low':7, 'High/Low':1, 'Medium/Medium':8, 'High/Medium':2,
       'High/High':0, 'Medium/High':6, 'Low/High':3, 'Low/Medium':5, 'Low/Low':4}
b = {'CAM':0, 'LS':13, 'GK':5, 'ST':27, 'LW':14, 'RCM':19, 'LCB':8, 'RW':25, 'SUB':28, 'CF':3,
       'CDM':2, 'RDM':20, 'RS':24, 'LCM':9, 'RB':17, 'LB':7, 'LM':12, 'RCB':18, 'LF':11, 'CB':1,
       'RM':23, 'LDM':10, 'RF':22, 'RES':21, 'LWB':15, 'CM':4, 'LAM':6, 'RWB':26, 'RAM':16}
c = {'Left':0,'Right':1}
df2['work_rate'] = df2['work_rate'].map(a)
df2['team_position'] = df2['team_position'].map(b)
df2['preferred_foot'] = df2['preferred_foot'].map(c)

# %%
df2
# Out:
#             short_name  preferred_foot  team_position  weak_foot  skill_moves  \
# 0       Ilias Akhomach               0             25          4            4
# 1              Ez Abde               1             14          4            4
# 2      Matheus Pereira               0             16          3            3
# 3  Maarten Vandevoordt               1              5          2            1
# 4        M Morgenstern               1              1          2            2
# 5              V dican               1              7          3            3
# 6              J seelt               0              1          4            2
# 7             L Stanga               1             27          3            4
# 8          Manu Martos               0              4          3            5
#
#    age  work_rate  team_jersey_number  pace  shooting  ...  \
# 0   17          8                  27    85        70  ...
# 1   20          2                  20    85        75  ...
# ...

# %% [markdown]
# ##Predicting the Result

# %%
df2.columns.get_loc('player_positions')
# Out:
# 53

# %%
X1_ = df2.iloc[:,1:53].values
X2_ = df2.iloc[:,2:53].values

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
X1_ = sc.fit_transform(X1_)
X2_ = sc.fit_transform(X2_)

# %%
y1_pred = classifier.predict(X1_)

# %%
df2['player_positions'][0]
# Out:
# nan

# %%
for i in range(len(y1_pred)):
  df2['player_positions'][i] = y1_pred[i]
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/indexing.py:1732: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self._setitem_single_block(indexer, value, name)

# %%
y_pred = regressor1.predict(poly_reg.fit_transform(X2_))

# %%
for i in range(len(y_pred)):
  df2['overall'][i] = int(y_pred[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
y_pred2 = regressor2.predict(poly_reg_.fit_transform(X2_))

# %%
for i in range(len(y_pred2)):
  df2['potential'][i] = int(y_pred2[i])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
df2
# Out:
#             short_name  preferred_foot  team_position  weak_foot  skill_moves  \
# 0       Ilias Akhomach               0             25          4            4
# 1              Ez Abde               1             14          4            4
# 2      Matheus Pereira               0             16          3            3
# 3  Maarten Vandevoordt               1              5          2            1
# 4        M Morgenstern               1              1          2            2
# 5              V dican               1              7          3            3
# 6              J seelt               0              1          4            2
# 7             L Stanga               1             27          3            4
# 8          Manu Martos               0              4          3            5
#
#    age  work_rate  team_jersey_number  pace  shooting  ...  \
# 0   17          8                  27    85        70  ...
# 1   20          2                  20    85        75  ...
# ...
